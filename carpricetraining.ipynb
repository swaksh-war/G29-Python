# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('carpricetraining.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
df.sample()
# Out:
#       Unnamed: 0                       Name Location  Year  Kilometers_Driven  \
# 4729        4729  Hyundai Verna Xi (Petrol)  Chennai  2009              60000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine      Power  Seats  \
# 4729    Petrol       Manual      Third  13.9 kmpl  1599 CC  103.2 bhp    5.0
#
#      New_Price  Price
# 4729       NaN   2.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
df2=df.drop('Unnamed: 0', axis=1, inplace=False)

# %%
df2.sample()
# Out:
#                           Name Location  Year  Kilometers_Driven Fuel_Type  \
# 920  Tata Indigo eCS eLX BS IV    Delhi  2015             150000    Diesel
#
#     Transmission Owner_Type    Mileage   Engine      Power  Seats New_Price  \
# 920       Manual      First  25.0 kmpl  1396 CC  69.01 bhp    5.0       NaN
#
#      Price
# 920    2.5

# %%
df.sample()
# Out:
#       Unnamed: 0                  Name   Location  Year  Kilometers_Driven  \
# 2765        2765  Honda Amaze S i-DTEC  Ahmedabad  2014              20000
#
#      Fuel_Type Transmission Owner_Type    Mileage   Engine     Power  Seats  \
# 2765    Diesel       Manual     Second  25.8 kmpl  1498 CC  98.6 bhp    5.0
#
#      New_Price  Price
# 2765       NaN    4.5

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.sample()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 5099  Maruti Alto K10 2010-2014 VXI  Coimbatore  2012              65349
#
#      Fuel_Type Transmission Owner_Type     Mileage  Engine     Power  Seats  \
# 5099    Petrol       Manual      First  20.92 kmpl  998 CC  67.1 bhp    5.0
#
#      New_Price  Price
# 5099       NaN   2.81

# %%
df.drop('New_Price', axis=1, inplace=True)

# %%
df.sample()
# Out:
#                          Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 2789  Maruti Baleno Delta 1.2  Coimbatore  2018              25093    Petrol
#
#      Transmission Owner_Type    Mileage   Engine     Power  Seats  Price
# 2789       Manual      First  21.4 kmpl  1197 CC  83.1 bhp    5.0   7.76

# %%
model_names = df['Name'].unique()

# %%
model_names
# Out:
# array(['Maruti Wagon R LXI CNG', 'Hyundai Creta 1.6 CRDi SX Option',
#        'Honda Jazz V', ..., 'Volkswagen Polo IPL II 1.2 Petrol Highline',
#        'Tata Bolt Revotron XT', 'Mahindra Xylo D4 BSIV'], dtype=object)

# %%
car_names=df['Name'].str.split(' ', expand=True)

# %%
car_companies , car_model = car_names[0], car_names[1]

# %%
df['Car_Companies'], df['Car_model'] = car_companies, car_model

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price Car_Companies Car_model
# 0   1.75        Maruti     Wagon
# 1  12.50       Hyundai     Creta
# 2   4.50         Honda      Jazz
# 3   6.00        Maruti    Ertiga
# 4  17.74          Audi        A4

# %%
df.drop(['Name'], axis=1,inplace=True)

# %%
df.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0      Mumbai  2010              72000       CNG       Manual      First
# 1        Pune  2015              41000    Diesel       Manual      First
# 2     Chennai  2011              46000    Petrol       Manual      First
# 3     Chennai  2012              87000    Diesel       Manual      First
# 4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#       Mileage   Engine      Power  Seats  Price Car_Companies Car_model
# 0  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75        Maruti     Wagon
# 1  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50       Hyundai     Creta
# 2   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50         Honda      Jazz
# 3  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00        Maruti    Ertiga
# 4   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74          Audi        A4

# %%
df['Car_model'] = df['Car_model'].apply(lambda x : x.lower())

# %%
df.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0      Mumbai  2010              72000       CNG       Manual      First
# 1        Pune  2015              41000    Diesel       Manual      First
# 2     Chennai  2011              46000    Petrol       Manual      First
# 3     Chennai  2012              87000    Diesel       Manual      First
# 4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#       Mileage   Engine      Power  Seats  Price Car_Companies Car_model
# 0  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75        Maruti     wagon
# 1  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50       Hyundai     creta
# 2   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50         Honda      jazz
# 3  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00        Maruti    ertiga
# 4   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74          Audi        a4

# %%
df.drop(['Year', 'Kilometers_Driven', 'Owner_Type'], axis=1, inplace=True)

# %%
df.head()
# Out:
#      Location Fuel_Type Transmission     Mileage   Engine      Power  Seats  \
# 0      Mumbai       CNG       Manual  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1        Pune    Diesel       Manual  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2     Chennai    Petrol       Manual   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3     Chennai    Diesel       Manual  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4  Coimbatore    Diesel    Automatic   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price Car_Companies Car_model
# 0   1.75        Maruti     wagon
# 1  12.50       Hyundai     creta
# 2   4.50         Honda      jazz
# 3   6.00        Maruti    ertiga
# 4  17.74          Audi        a4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       6019 non-null   object
#  1   Fuel_Type      6019 non-null   object
#  2   Transmission   6019 non-null   object
#  3   Mileage        6017 non-null   object
#  4   Engine         5983 non-null   object
#  5   Power          5983 non-null   object
#  6   Seats          5977 non-null   float64
#  7   Price          6019 non-null   float64
#  8   Car_Companies  6019 non-null   object
#  9   Car_model      6019 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 470.4+ KB

# %%
def convert_to_number(x):
    res = ''
    for char in x:
        if char.isdigit() or char =='.':
            res += char
    try :
        return float(res)
    except :
        return None

convert_to_number('998 CC')
# Out:
# 998.0

# %%
df['Engine']
# Out:
# 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 6019, dtype: object

# %%
df['Engine'] = df['Engine'].apply(lambda x : convert_to_number(str(x)))

# %%
df['Mileage'] = df['Mileage'].apply(lambda x : convert_to_number(str(x)))

# %%
df['Power'] = df['Power'].apply(lambda x : convert_to_number(str(x)))

# %%
df.head()
# Out:
#      Location Fuel_Type Transmission  Mileage  Engine   Power  Seats  Price  \
# 0      Mumbai       CNG       Manual    26.60   998.0   58.16    5.0   1.75
# 1        Pune    Diesel       Manual    19.67  1582.0  126.20    5.0  12.50
# 2     Chennai    Petrol       Manual    18.20  1199.0   88.70    5.0   4.50
# 3     Chennai    Diesel       Manual    20.77  1248.0   88.76    7.0   6.00
# 4  Coimbatore    Diesel    Automatic    15.20  1968.0  140.80    5.0  17.74
#
#   Car_Companies Car_model
# 0        Maruti     wagon
# 1       Hyundai     creta
# 2         Honda      jazz
# 3        Maruti    ertiga
# 4          Audi        a4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       6019 non-null   object
#  1   Fuel_Type      6019 non-null   object
#  2   Transmission   6019 non-null   object
#  3   Mileage        6017 non-null   float64
#  4   Engine         5983 non-null   float64
#  5   Power          5876 non-null   float64
#  6   Seats          5977 non-null   float64
#  7   Price          6019 non-null   float64
#  8   Car_Companies  6019 non-null   object
#  9   Car_model      6019 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 470.4+ KB

# %%
fuel_types_list = df['Fuel_Type'].unique().tolist()
transmission_type_list = df['Transmission'].unique().tolist()

# %%
df2 = df[(df['Fuel_Type'] == 'Petrol') & (df['Transmission'] == 'Automatic')]

# %%
df2.head()
# Out:
#      Location Fuel_Type Transmission  Mileage  Engine   Power  Seats  Price  \
# 11    Kolkata    Petrol    Automatic    16.80  1497.0  116.30    5.0   4.49
# 22     Mumbai    Petrol    Automatic    13.53  1984.0  177.01    5.0  23.50
# 24    Kolkata    Petrol    Automatic    14.40  1598.0  103.60    5.0   2.85
# 44  Bangalore    Petrol    Automatic    14.62  1999.0  149.92    5.0   8.85
# 45     Mumbai    Petrol    Automatic    14.28  1798.0  138.03    5.0  10.11
#
#    Car_Companies Car_model
# 11         Honda      city
# 22          Audi        a6
# 24    Volkswagen     vento
# 44       Hyundai   elantra
# 45        Toyota   corolla

# %%
filtered_data = {}
for fuel_type in fuel_types_list:
    for transmission in transmission_type_list:
        filtered_data[f'df_{fuel_type}_{transmission}'] = df[(df['Fuel_Type'] == fuel_type) & (df['Transmission'] == transmission)]

# %%
filtered_data.keys()
# Out:
# dict_keys(['df_CNG_Manual', 'df_CNG_Automatic', 'df_Diesel_Manual', 'df_Diesel_Automatic', 'df_Petrol_Manual', 'df_Petrol_Automatic', 'df_LPG_Manual', 'df_LPG_Automatic', 'df_Electric_Manual', 'df_Electric_Automatic'])

# %%
filtered_data.pop('df_CNG_Automatic')
filtered_data.pop('df_LPG_Automatic')
filtered_data.pop('df_Electric_Manual')
# Out:
# Empty DataFrame
# Columns: [Location, Fuel_Type, Transmission, Mileage, Engine, Power, Seats, Price, Car_Companies, Car_model]
# Index: []

# %%
filtered_data.keys()
# Out:
# dict_keys(['df_CNG_Manual', 'df_Diesel_Manual', 'df_Diesel_Automatic', 'df_Petrol_Manual', 'df_Petrol_Automatic', 'df_LPG_Manual', 'df_Electric_Automatic'])

# %%
filtered_data_engine_mean = {}

for _key, _df in filtered_data.items():
    filtered_data_engine_mean[f"{_key}_engine_mean"] = _df['Engine'].mean()

# %%
filtered_data_engine_mean
# Out:
# {'df_CNG_Manual_engine_mean': 1091.0535714285713,
#  'df_Diesel_Manual_engine_mean': 1635.5815839694656,
#  'df_Diesel_Automatic_engine_mean': 2291.879200726612,
#  'df_Petrol_Manual_engine_mean': 1238.1782835467045,
#  'df_Petrol_Automatic_engine_mean': 1747.1231527093596,
#  'df_LPG_Manual_engine_mean': 1027.4,
#  'df_Electric_Automatic_engine_mean': 935.0}

# %%
filtered_data_mileage_mean = {}

for _key, _df in filtered_data.items():
    filtered_data_mileage_mean[f"{_key}_mileage_mean"] = _df['Mileage'].mean()

# %%
filtered_data_power_mean = {}

for _key, _df in filtered_data.items():
    filtered_data_power_mean[f"{_key}_power_mean"] = _df['Power'].mean()

# %%
filtered_data_mileage_mean, filtered_data_power_mean
# Out:
# ({'df_CNG_Manual_mileage_mean': 25.41803571428571,
#   'df_Diesel_Manual_mileage_mean': 20.164668574153552,
#   'df_Diesel_Automatic_mileage_mean': 15.697960288808664,
#   'df_Petrol_Manual_mileage_mean': 17.88815074906367,
#   'df_Petrol_Automatic_mileage_mean': 15.759114754098363,
#   'df_LPG_Manual_mileage_mean': 19.384999999999998,
#   'df_Electric_Automatic_mileage_mean': nan},
#  {'df_CNG_Manual_power_mean': 64.83090909090909,
#   'df_Diesel_Manual_power_mean': 98.35133885102239,
#   'df_Diesel_Automatic_power_mean': 183.13458598726115,
#   'df_Petrol_Manual_power_mean': 84.68131027764248,
#   'df_Petrol_Automatic_power_mean': 139.4142288557214,
#   'df_LPG_Manual_power_mean': 59.915000000000006,
#   'df_Electric_Automatic_power_mean': 57.0})

# %%
global_mileage_mean = df['Mileage'].mean()

# %%
filtered_data_mileage_mean["df_Electric_Automatic_mileage_mean"] = global_mileage_mean

# %%
filtered_data_mileage_mean
# Out:
# {'df_CNG_Manual_mileage_mean': 25.41803571428571,
#  'df_Diesel_Manual_mileage_mean': 20.164668574153552,
#  'df_Diesel_Automatic_mileage_mean': 15.697960288808664,
#  'df_Petrol_Manual_mileage_mean': 17.88815074906367,
#  'df_Petrol_Automatic_mileage_mean': 15.759114754098363,
#  'df_LPG_Manual_mileage_mean': 19.384999999999998,
#  'df_Electric_Automatic_mileage_mean': 18.134960943992024}

# %%
for _key, _df in filtered_data.items():
    _df['Engine'] = _df['Engine'].fillna(filtered_data_engine_mean[f"{_key}_engine_mean"])
    _df['Mileage'] = _df['Mileage'].fillna(filtered_data_mileage_mean[f"{_key}_mileage_mean"])
    _df["Power"] = _df["Power"].fillna(filtered_data_power_mean[f"{_key}_power_mean"])
# Out:
# C:\Users\Swakshwar Ghosh\AppData\Local\Temp\ipykernel_4040\2942221618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['Engine'] = _df['Engine'].fillna(filtered_data_engine_mean[f"{_key}_engine_mean"])
# C:\Users\Swakshwar Ghosh\AppData\Local\Temp\ipykernel_4040\2942221618.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['Mileage'] = _df['Mileage'].fillna(filtered_data_mileage_mean[f"{_key}_mileage_mean"])
# C:\Users\Swakshwar Ghosh\AppData\Local\Temp\ipykernel_4040\2942221618.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df["Power"] = _df["Power"].fillna(filtered_data_power_mean[f"{_key}_power_mean"])

# %%
df2 = pd.concat([_df for _, _df in filtered_data.items()])

# %%
df2.shape
# Out:
# (6019, 10)

# %%
carData = df2

# %%
carData.head()
# Out:
#     Location Fuel_Type Transmission  Mileage  Engine  Power  Seats  Price  \
# 0     Mumbai       CNG       Manual    26.60   998.0  58.16    5.0   1.75
# 127     Pune       CNG       Manual    26.60   998.0  58.16    5.0   3.25
# 328     Pune       CNG       Manual    26.30   998.0  67.10    5.0   1.40
# 440    Kochi       CNG       Manual    15.10  1196.0  73.00    5.0   4.70
# 839    Delhi       CNG       Manual    26.83   796.0  38.40    5.0   2.10
#
#     Car_Companies Car_model
# 0          Maruti     wagon
# 127        Maruti     wagon
# 328        Maruti       zen
# 440        Maruti      eeco
# 839        Maruti      alto

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: seaborn in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\swakshwar ghosh\appdata\roaming\python\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\swakshwar ghosh\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\swakshwar ghosh\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: six in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swakshwar ghosh\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(carData['Car_Companies'])
# Out:
# <Axes: xlabel='count', ylabel='Car_Companies'>

# %%
sns.countplot(carData['Car_model'])
# Out:
# <Axes: xlabel='count', ylabel='Car_model'>

# %%
import matplotlib.pyplot as plt

# %%
bar_chart_values = [10, 20, 30, 35]
bar_chart_labels = ['Label 1', 'Label 2', 'Label 3', 'Label 4']
plt.bar(bar_chart_labels, bar_chart_values)
plt.show()

# %%
pie_chart_labels = ['Label 1', 'Label 2', 'Label 3', 'Label 4']
pie_chart_values = [10, 20, 30, 40]

plt.pie(pie_chart_values, labels=pie_chart_labels)
plt.legend()
plt.show()

# %%
line_chart_x = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
line_chart_y = [100, 106, 112, 119, 126, 135, 140, 150, 166, 156, 170, 166, 170]
line_chart_y2 = [100, 110, 120, 130, 125, 130, 132, 121, 180, 110, 121, 132, 143]
plt.plot(line_chart_x, line_chart_y)
plt.plot(line_chart_x, line_chart_y2)
plt.xlabel('Year')
plt.ylabel('Price')
plt.plot()
# Out:
# []

# %%
import numpy as np

# %%
data = [np.random.normal(0, i, 100) for i in range(1, 5)]
print(data)
plt.boxplot(data, vert=True, patch_artist=True)
plt.xticks([1, 2, 3, 4], ['Category 1', 'Category 2', 'Category 3', 'Category 4'])
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Box plot')
plt.show()
# Out:
# [array([-3.09333617, -0.56527899,  0.28007159,  0.899134  , -1.49095032,
#         0.16680827, -0.42249523, -1.75942521,  0.38507231,  1.00816638,
#         0.70805306, -2.1854184 , -0.70706754,  0.42974766,  1.22025708,
#        -0.21339995, -0.27052958,  0.65070757, -1.31073023,  0.30028766,
#        -1.83028514, -0.26148109, -0.64550734, -1.86440012,  2.49241792,
#         0.47053591, -0.81051076,  0.44710667,  0.80271926,  0.73791508,
#        -0.70935911,  0.31932507, -1.03467683,  0.62854162, -2.31030811,
#         1.45887568, -1.06220559, -0.43614935,  0.07406949, -1.06048769,
#         0.17695027,  1.42642447, -0.21118482,  1.25953915,  0.10300864,
#         0.05178505,  0.72484239, -0.04285467, -1.16981787,  0.89456751,
#         1.66955871, -0.27520968,  0.59871584,  0.82600888,  0.03546063,
#        -2.30546546, -0.48140404,  1.03701501, -0.01657152, -0.53044688,
#        -1.36427145,  0.10832164,  2.33700992,  0.90702701,  0.17265532,
#        -0.35834045,  0.4117234 ,  0.37004143, -1.80655037, -1.37068868,
#        -1.27353386,  0.0172637 , -0.15472854, -0.23582838, -0.32115397,
#        -0.8177788 , -2.56215892, -0.49365856,  0.73157439,  0.80206252,
#        -1.05559418,  1.12230152,  0.1209633 ,  0.88043187,  1.32596322,
#        -0.51746643, -0.32979156,  1.06140831, -0.1108484 ,  1.56805083,
#        -0.70904141,  0.4256116 ,  0.39430021, -2.08910544, -2.7717197 ,
#        -1.62012227,  0.02351529, -1.06551269,  1.6561849 , -0.68085553]), array([ 1.86533712, -2.25626804,  2.46220196, -1.20505098,  0.886076  ,
#         3.3319716 , -0.60144633,  2.90059161,  0.7944074 , -1.84149495,
#         1.94020999, -2.24052475,  0.21009409,  0.25852157,  3.78773807,
#         0.96783283,  3.77365822, -2.0628113 , -3.84914513, -4.58091095,
#        -0.51256504,  1.58499963,  2.10242456,  1.61580549,  1.79557468,
#        -0.11307228, -0.40415553,  1.44682342,  2.15496328, -0.44663762,
#        -2.42608933,  0.01351084, -0.20690593, -0.53756422, -0.02525348,
#        -1.06065109, -2.88547723, -1.31032871, -3.76001442,  1.05510433,
#        -0.11309452,  3.26616142, -4.39726032,  2.80868646, -0.70913205,
#        -1.3408238 ,  1.95245842,  0.1691357 ,  0.78179552,  2.97131606,
#         0.22234613, -0.50074015,  1.10035106, -0.40866121,  0.16673438,
#        -1.09697366,  0.46688672, -0.27205231,  4.77311346, -1.87256092,
#         1.49312633,  0.74959893,  0.30250156,  0.8885608 , -2.98770465,
#        -0.16359632, -2.71933473, -4.82040821, -1.98111151,  3.30796075,
#         3.54709701, -2.14551134, -1.03332712, -0.64755711,  3.05347269,
#        -2.75541805, -1.71002686,  2.75381872,  3.29149344,  4.73813041,
#         0.01724471,  2.17071237, -0.54305976,  1.21290831,  1.39554553,
#        -0.26283273,  3.31427352, -2.07913921,  1.42216475,  0.7730989 ,
#        -0.6762127 ,  0.04729654, -4.5098164 ,  3.95724234, -2.63602018,
#         1.5566899 , -1.73488164, -1.50239465, -3.85355303,  2.8996748 ]), array([ 7.24225572e+00,  1.41233382e+00,  2.15345952e+00, -1.64656898e+00,
#        -8.33216411e-01, -3.58498078e+00,  5.87335186e+00,  6.96225323e-01,
#        -1.68775641e+00,  6.25354382e-01,  1.02662860e-01,  4.94997683e+00,
#        -3.78640437e+00,  4.38176697e+00, -5.42358823e-01,  8.84892251e-01,
#        -5.90632136e-01,  1.12673901e+00, -2.58134307e+00,  2.99767153e+00,
#         1.37712087e+00, -4.64837701e-01, -4.26405346e+00,  2.70974271e+00,
#         3.70471998e+00, -3.84649710e-01, -2.75738746e+00,  1.02920155e+00,
#         2.46985882e+00,  3.92025986e+00, -2.12192205e+00, -4.35236248e-01,
#        -3.25310431e+00,  1.98684026e+00, -2.15125605e+00, -5.43486333e-01,
#        -5.14757907e+00, -3.08722155e+00,  5.26490310e+00,  7.50237486e-01,
#        -1.97668968e-01,  2.73111380e+00,  1.67628887e+00, -9.04212442e+00,
#         2.83199334e+00,  2.02781196e-02, -4.02715145e+00, -3.71931276e+00,
#         3.51785953e+00,  4.08112593e-01,  1.55799299e+00,  1.65871484e+00,
#         2.70014880e-02,  4.73839866e+00,  6.70194273e-01,  1.91476186e+00,
#        -2.48513740e+00,  2.51181113e+00,  2.13181151e+00,  4.41818642e-01,
#        -3.21621459e+00,  2.89321474e+00, -2.35266209e-01, -9.24780113e-01,
#        -2.69417121e+00, -4.67603061e+00, -3.75211655e+00, -2.31205541e+00,
#         3.52932020e+00, -7.99700545e-01,  3.52437902e+00,  4.44302726e+00,
#        -3.72700587e-01,  1.04870007e+00,  2.05671067e+00,  8.30809055e-01,
#         3.87865919e-01,  2.82752850e+00,  1.86418410e+00, -2.75166011e+00,
#         5.26501748e-01, -5.84798544e+00, -7.86596161e-02, -9.61647932e-01,
#         3.28092023e+00,  6.64663160e-01, -2.83325586e+00, -5.42548453e-01,
#         5.00619935e+00, -3.83673586e+00, -1.08563849e+00, -8.41588846e-01,
#        -3.53196195e+00,  9.55970587e-01, -1.98725962e+00,  7.87542769e+00,
#        -8.95795985e-03, -1.93076410e+00,  1.54565248e+00, -3.38551179e+00]), array([ 1.14655872, -3.42696486, -1.96131683, -6.71547221, -1.06472085,
#         0.83537826, -2.72229554, -7.18020061, -3.24803179,  5.6373118 ,
#        -2.62697482,  2.1546731 ,  3.47833205, -3.41602414,  4.3932566 ,
#         4.97497451, -0.60103275, -5.00197097, -2.94138956,  4.30929072,
#        -1.70411499, -8.25894336,  3.91033736, -6.59077949,  5.46509243,
#         0.90386819, -0.79988684,  2.40228053,  2.42606688,  2.32391597,
#         6.26539644, -6.81470718,  4.15016182,  8.21310796, -0.04359605,
#         3.67857679, -1.97059653, -0.05758536,  3.7372573 , -1.84205198,
#         0.52222549, -1.00459292, -1.1048499 , -6.20752139,  2.42445419,
#        -4.73186404,  2.93728119, -2.50902135,  6.02637959,  4.13981241,
#         2.15720251, -5.47226237, -3.08279957, -0.24462032,  2.63818544,
#         2.47978607,  0.35807936,  9.98788632,  2.08620552, -2.70277236,
#        -0.34137589, -0.47326448,  5.04918071, 10.53802442, -0.38967799,
#         1.07806451,  4.59947263, -3.33242593,  0.40418099,  3.12674144,
#        -7.48925245, -2.68440503, -3.11363972, -4.38556216, -0.06209025,
#        -1.13812257,  0.97969492, -1.85818214,  6.86554814,  3.92940778,
#        -1.74786088, -1.14028162, -1.12308579,  5.21305177,  4.61557016,
#        -4.50391071, -4.37895032, -0.22932456, -7.58821642, -0.77422169,
#        -3.11309227, -2.09908612, -1.14316419, -8.0263493 , -5.42642987,
#         6.06699311, -0.91342061,  0.20154717, -7.93341679, -0.14957816])]

# %%
import seaborn as sns

# %%
sns.pairplot(carData)

# %%
corr_data = carData[['Mileage', 'Engine', 'Power', 'Seats', 'Price']]
corr_matrix = corr_data.corr()

# %%
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >
